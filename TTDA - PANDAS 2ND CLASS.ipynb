# %%
# !pip install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/erikahartai/Library/Python/3.14/lib/python/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/erikahartai/Library/Python/3.14/lib/python/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/erikahartai/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/erikahartai/Library/Python/3.14/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/erikahartai/Library/Python/3.14/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/erikahartai/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
df2 = pd.DataFrame([('Foreign Cinema', 'Restaurant', 289.0),
                   ('Liho Liho', 'Restaurant', 224.0),
                   ('500 Club', 'bar', 80.5),
                   ('The Square', 'bar', 25.30)],
           columns=('name', 'type', 'AvgBill')
                 )
df2
# Out:
#              name        type  AvgBill
# 0  Foreign Cinema  Restaurant    289.0
# 1       Liho Liho  Restaurant    224.0
# 2        500 Club         bar     80.5
# 3      The Square         bar     25.3

# %%
df2['Day'] = "Monday" # Como un diccionario
df2
# Out:
#              name        type  AvgBill     Day
# 0  Foreign Cinema  Restaurant    289.0  Monday
# 1       Liho Liho  Restaurant    224.0  Monday
# 2        500 Club         bar     80.5  Monday
# 3      The Square         bar     25.3  Monday

# %%
#Vamos a usar el método insert
df2.insert(loc=1, column="Stars", value=[2,2,3,4])
df2
# Out:
#              name  Stars        type  AvgBill     Day
# 0  Foreign Cinema      2  Restaurant    289.0  Monday
# 1       Liho Liho      2  Restaurant    224.0  Monday
# 2        500 Club      3         bar     80.5  Monday
# 3      The Square      4         bar     25.3  Monday

# %%
df2["AvgBillIVA"] = df2["AvgBill"]*1.21
df2
# Out:
#              name  Stars        type  AvgBill     Day  AvgBillIVA
# 0  Foreign Cinema      2  Restaurant    289.0  Monday     349.690
# 1       Liho Liho      2  Restaurant    224.0  Monday     271.040
# 2        500 Club      3         bar     80.5  Monday      97.405
# 3      The Square      4         bar     25.3  Monday      30.613

# %%
df3 = df2.assign(AvgHalfBill=df2.AvgBill / 2, Michelin_Star=3)
df3

df3["HOLA"] = df3.name.str.capitalize()
df3
# Out:
#              name  Stars        type  AvgBill     Day  AvgBillIVA  \
# 0  Foreign Cinema      2  Restaurant    289.0  Monday     349.690
# 1       Liho Liho      2  Restaurant    224.0  Monday     271.040
# 2        500 Club      3         bar     80.5  Monday      97.405
# 3      The Square      4         bar     25.3  Monday      30.613
#
#    AvgHalfBill  Michelin_Star            HOLA
# 0       144.50              3  Foreign cinema
# 1       112.00              3       Liho liho
# 2        40.25              3        500 club
# 3        12.65              3      The square

# %%
df3.drop(columns=["Stars"],inplace=True) # Eliminamos la última columna que hemos creado

# %%
df3
# Out:
#              name        type  AvgBill     Day  AvgBillIVA  AvgHalfBill  \
# 0  Foreign Cinema  Restaurant    289.0  Monday     349.690       144.50
# 1       Liho Liho  Restaurant    224.0  Monday     271.040       112.00
# 2        500 Club         bar     80.5  Monday      97.405        40.25
# 3      The Square         bar     25.3  Monday      30.613        12.65
#
#    Michelin_Star            HOLA
# 0              3  Foreign cinema
# 1              3       Liho liho
# 2              3        500 club
# 3              3      The square

# %%
df_less_rows = df_no_michelin.drop([1,3])
df_less_rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_less_rows = df_no_michelin.drop([1,3])
#       2 df_less_rows
#
# NameError: name 'df_no_michelin' is not defined

# %%
dfs1 = df3[df3.Michelin_Star>=3] # per una selecció?
dfs1
# Out:
#              name        type  AvgBill     Day  AvgBillIVA  AvgHalfBill  \
# 0  Foreign Cinema  Restaurant    289.0  Monday     349.690       144.50
# 1       Liho Liho  Restaurant    224.0  Monday     271.040       112.00
# 2        500 Club         bar     80.5  Monday      97.405        40.25
# 3      The Square         bar     25.3  Monday      30.613        12.65
#
#    Michelin_Star            HOLA
# 0              3  Foreign cinema
# 1              3       Liho liho
# 2              3        500 club
# 3              3      The square

# %%
df3[df3.Michelin_Star>=3].index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df3.drop(df3[df3.Michelin_Star>=3].index, inplace=True) #Alerta con la integración de los cambios
df3
# Out:
# Empty DataFrame
# Columns: [name, type, AvgBill, Day, AvgBillIVA, AvgHalfBill, Michelin_Star, HOLA]
# Index: []

# %%
#Concatenación y unión de dataframes

# %%
df1 = pd.DataFrame([('Foreign Cinema', 'Restaurant', 289.0),
                   ('Liho Liho', 'Restaurant', 224.0),
                   ('500 Club', 'bar', 80.5),
                   ('The Square', 'bar', 25.30)],
           columns=('name', 'type', 'AvgBill')
                 )
df1
# Out:
#              name        type  AvgBill
# 0  Foreign Cinema  Restaurant    289.0
# 1       Liho Liho  Restaurant    224.0
# 2        500 Club         bar     80.5
# 3      The Square         bar     25.3

# %%
df2 = pd.DataFrame([('Biels', 'Quiosquet', 389.0),
                   ('Barkus', 'Bar', 24.0),
                   ('Blue Wall', 'bar', 80.5),
                   ('Bounty Hunters', 'Social Club', 125.30)],
           columns=('name2', 'type', 'AvgBill')
                 )
df2
# Out:
#             name2         type  AvgBill
# 0           Biels    Quiosquet    389.0
# 1          Barkus          Bar     24.0
# 2       Blue Wall          bar     80.5
# 3  Bounty Hunters  Social Club    125.3

# %%
dfAll = pd.concat([df1,df2])
dfAll
# Out:
#              name         type  AvgBill           name2
# 0  Foreign Cinema   Restaurant    289.0             NaN
# 1       Liho Liho   Restaurant    224.0             NaN
# 2        500 Club          bar     80.5             NaN
# 3      The Square          bar     25.3             NaN
# 0             NaN    Quiosquet    389.0           Biels
# 1             NaN          Bar     24.0          Barkus
# 2             NaN          bar     80.5       Blue Wall
# 3             NaN  Social Club    125.3  Bounty Hunters

# %%
dfAll = dfAll.reset_index()
dfAll
# Out:
#    index            name         type  AvgBill           name2
# 0      0  Foreign Cinema   Restaurant    289.0             NaN
# 1      1       Liho Liho   Restaurant    224.0             NaN
# 2      2        500 Club          bar     80.5             NaN
# 3      3      The Square          bar     25.3             NaN
# 4      0             NaN    Quiosquet    389.0           Biels
# 5      1             NaN          Bar     24.0          Barkus
# 6      2             NaN          bar     80.5       Blue Wall
# 7      3             NaN  Social Club    125.3  Bounty Hunters

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html
dfAll = pd.concat([df1,df2],ignore_index=True)
dfAll
# Out:
#              name         type  AvgBill           name2
# 0  Foreign Cinema   Restaurant    289.0             NaN
# 1       Liho Liho   Restaurant    224.0             NaN
# 2        500 Club          bar     80.5             NaN
# 3      The Square          bar     25.3             NaN
# 4             NaN    Quiosquet    389.0           Biels
# 5             NaN          Bar     24.0          Barkus
# 6             NaN          bar     80.5       Blue Wall
# 7             NaN  Social Club    125.3  Bounty Hunters

# %%
df1 = pd.DataFrame([('Jhon', 1, "Italy"),
                   ('Pep', 2, "Germany"),
                   ('William', 3, "Finland"),
                   ('Snake', 4, "Italy")],
           columns=('name', 'ID', 'Country')
                 )
df1
# Out:
#       name  ID  Country
# 0     Jhon   1    Italy
# 1      Pep   2  Germany
# 2  William   3  Finland
# 3    Snake   4    Italy

# %%
df2 = pd.DataFrame([(1, 145.0, 3000.1),
                   ( 2, 189.2, 2030.2),
                   ( 3, 129.0, 3000.0),
                   ( 4, 198.1, 4020.2)],
           columns=('DNI', 'Weight', 'Salary')
                 )
df2
# Out:
#    DNI  Weight  Salary
# 0    1   145.0  3000.1
# 1    2   189.2  2030.2
# 2    3   129.0  3000.0
# 3    4   198.1  4020.2

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

df1.merge(df2) ## ALERTA ! Necesita más parametros
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[33], line 3
#       1 # https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
# ----> 3 df1.merge(df2) ## ALERTA ! Necesita más parametros
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/frame.py:10859, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10840 @Substitution("")
#   10841 @Appender(_merge_doc, indents=2)
#   10842 def merge(
#    (...)  10855     validate: MergeValidate | None = None,
#   10856 ) -> DataFrame:
#   10857     from pandas.core.reshape.merge import merge
# > 10859     return merge(
#   10860         self,
#   10861         right,
#   10862         how=how,
#   10863         on=on,
#   10864         left_on=left_on,
#   10865         right_on=right_on,
#   10866         left_index=left_index,
#   10867         right_index=right_index,
#   10868         sort=sort,
#   10869         suffixes=suffixes,
#   10870         copy=copy,
#   10871         indicator=indicator,
#   10872         validate=validate,
#   10873     )
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/reshape/merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)    167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/reshape/merge.py:786, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     779     msg = (
#     780         "Not allowed to merge between different levels. "
#     781         f"({_left.columns.nlevels} levels on the left, "
#     782         f"{_right.columns.nlevels} on the right)"
#     783     )
#     784     raise MergeError(msg)
# --> 786 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     788 (
#     789     self.left_join_keys,
#     790     self.right_join_keys,
#    (...)    793     right_drop,
#     794 ) = self._get_merge_keys()
#     796 if left_drop:
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/reshape/merge.py:1573, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1571 common_cols = left_cols.intersection(right_cols)
#    1572 if len(common_cols) == 0:
# -> 1573     raise MergeError(
#    1574         "No common columns to perform merge on. "
#    1575         f"Merge options: left_on={left_on}, "
#    1576         f"right_on={right_on}, "
#    1577         f"left_index={self.left_index}, "
#    1578         f"right_index={self.right_index}"
#    1579     )
#    1580 if (
#    1581     not left_cols.join(common_cols, how="inner").is_unique
#    1582     or not right_cols.join(common_cols, how="inner").is_unique
#    1583 ):
#    1584     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
df1.merge(df2, left_on='ID', right_on='DNI')
# Out:
#       name  ID  Country  DNI  Weight  Salary
# 0     Jhon   1    Italy    1   145.0  3000.1
# 1      Pep   2  Germany    2   189.2  2030.2
# 2  William   3  Finland    3   129.0  3000.0
# 3    Snake   4    Italy    4   198.1  4020.2

# %%
df2 = pd.DataFrame([(1, 145.0, 3000.1), #No 2
                   ( 3, 129.0, 3000.0), # Multiples 3
                   ( 3, 159.0, 4000.0),
                   ( 3, 109.0, 5000.0),
                   ( 4, 198.1, 4020.2),
                   ( 5, 200.0, 5000.2)], #a new one
           columns=('DNI', 'Weight', 'Salary')
                 )
df2
# Out:
#    DNI  Weight  Salary
# 0    1   145.0  3000.1
# 1    3   129.0  3000.0
# 2    3   159.0  4000.0
# 3    3   109.0  5000.0
# 4    4   198.1  4020.2
# 5    5   200.0  5000.2

# %%
df1.merge(df2, left_on='ID', right_on='DNI')
# Out:
#       name  ID  Country  DNI  Weight  Salary
# 0     Jhon   1    Italy    1   145.0  3000.1
# 1  William   3  Finland    3   129.0  3000.0
# 2  William   3  Finland    3   159.0  4000.0
# 3  William   3  Finland    3   109.0  5000.0
# 4    Snake   4    Italy    4   198.1  4020.2

# %%
df1.merge(df2, left_on='ID', right_on='DNI',how="left")
# Out:
#       name  ID  Country  DNI  Weight  Salary
# 0     Jhon   1    Italy  1.0   145.0  3000.1
# 1      Pep   2  Germany  NaN     NaN     NaN
# 2  William   3  Finland  3.0   129.0  3000.0
# 3  William   3  Finland  3.0   159.0  4000.0
# 4  William   3  Finland  3.0   109.0  5000.0
# 5    Snake   4    Italy  4.0   198.1  4020.2

# %%
df1.merge(df2, left_on='ID', right_on='DNI',how="right")
# Out:
#       name   ID  Country  DNI  Weight  Salary
# 0     Jhon  1.0    Italy    1   145.0  3000.1
# 1  William  3.0  Finland    3   129.0  3000.0
# 2  William  3.0  Finland    3   159.0  4000.0
# 3  William  3.0  Finland    3   109.0  5000.0
# 4    Snake  4.0    Italy    4   198.1  4020.2
# 5      NaN  NaN      NaN    5   200.0  5000.2

# %%
df1.merge(df2, left_on='ID', right_on='DNI',how="inner")
# Out:
#       name  ID  Country  DNI  Weight  Salary
# 0     Jhon   1    Italy    1   145.0  3000.1
# 1  William   3  Finland    3   129.0  3000.0
# 2  William   3  Finland    3   159.0  4000.0
# 3  William   3  Finland    3   109.0  5000.0
# 4    Snake   4    Italy    4   198.1  4020.2

# %%
df1.merge(df2,how="cross")
# Out:
#        name  ID  Country  DNI  Weight  Salary
# 0      Jhon   1    Italy    1   145.0  3000.1
# 1      Jhon   1    Italy    3   129.0  3000.0
# 2      Jhon   1    Italy    3   159.0  4000.0
# 3      Jhon   1    Italy    3   109.0  5000.0
# 4      Jhon   1    Italy    4   198.1  4020.2
# 5      Jhon   1    Italy    5   200.0  5000.2
# 6       Pep   2  Germany    1   145.0  3000.1
# 7       Pep   2  Germany    3   129.0  3000.0
# 8       Pep   2  Germany    3   159.0  4000.0
# 9       Pep   2  Germany    3   109.0  5000.0
# 10      Pep   2  Germany    4   198.1  4020.2
# 11      Pep   2  Germany    5   200.0  5000.2
# 12  William   3  Finland    1   145.0  3000.1
# 13  William   3  Finland    3   129.0  3000.0
# 14  William   3  Finland    3   159.0  4000.0
# 15  William   3  Finland    3   109.0  5000.0
# 16  William   3  Finland    4   198.1  4020.2
# 17  William   3  Finland    5   200.0  5000.2
# 18    Snake   4    Italy    1   145.0  3000.1
# 19    Snake   4    Italy    3   129.0  3000.0
# 20    Snake   4    Italy    3   159.0  4000.0
# 21    Snake   4    Italy    3   109.0  5000.0
# 22    Snake   4    Italy    4   198.1  4020.2
# 23    Snake   4    Italy    5   200.0  5000.2

# %%
# read file csv
import pandas as pd
df_who = pd.read_csv("WHO.csv")
df_who.head()
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1          1                          151.0
# 1      Albania          2          2                           27.0
# 2      Algeria          3          3                            6.0
# 3      Andorra          4          2                            NaN
# 4       Angola          5          3                          146.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
# 2                     69.9
# 3                      NaN
# 4                     67.4
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
# 3                                                NaN
# 4                                             3890.0
#
#    Net primary school enrolment ratio female (%)  \
# 0                                            NaN
# 1                                           93.0
# 2                                           94.0
# 3                                           83.0
# 4                                           49.0
#
#    Net primary school enrolment ratio male (%)  \
# 0                                          NaN
# 1                                         94.0
# 2                                         96.0
# 3                                         83.0
# 4                                         51.0
#
#    Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                          26088.0                                4.0  ...
# 1                           3172.0                                0.6  ...
# 2                          33351.0                                1.5  ...
# 3                             74.0                                1.0  ...
# 4                          16557.0                                2.8  ...
#
#    Total_CO2_emissions  Total_income  Total_reserves  \
# 0               692.50           NaN             NaN
# 1              3499.12  4.790000e+09           78.14
# 2            137535.56  6.970000e+10          351.36
# 3                  NaN           NaN             NaN
# 4              8991.46  1.490000e+10           27.13
#
#    Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                               NaN                         257.00
# 1                     -2.040000e+09                          18.47
# 2                      4.700000e+09                          40.00
# 3                               NaN                            NaN
# 4                      9.140000e+09                         164.10
#
#    Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                           231.9                     257.00
# 1                            15.5                      18.47
# 2                            31.2                      40.00
# 3                             NaN                        NaN
# 4                           242.5                     164.10
#
#    Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0         5740436.0                     5.44                           22.9
# 1         1431793.9                     2.21                           45.4
# 2        20800000.0                     2.61                           63.3
# 3               NaN                      NaN                            NaN
# 4         8578749.0                     4.14                           53.3
#
# [5 rows x 358 columns]

# %%
#1.¿Cuál és la media de la población urbana (“Urban_population”) de todos los países? ¿Su desviación típica (std)?

# %%
df_who["Urban_population"].mean()
# Out:
# np.float64(16657626.767446807)

# %%
df_who["Urban_population"].std()
# Out:
# np.float64(50948665.823935635)

# %%
#2) Consulta la fila del país: “Spain”

# %%
df_who[df_who["Country"]=="Spain"]
# Out:
#     Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 168   Spain        169          2                           10.0
#
#      Adult literacy rate (%)  \
# 168                     97.2
#
#      Gross national income per capita (PPP international $)  \
# 168                                            28200.0
#
#      Net primary school enrolment ratio female (%)  \
# 168                                           99.0
#
#      Net primary school enrolment ratio male (%)  \
# 168                                        100.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 168                          43887.0                                1.1  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 168            343701.53  6.780000e+11             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 168                     -5.770000e+10                            4.9
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 168                             4.2                        4.9
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 168        33300000.0                     1.75                           76.7
#
# [1 rows x 358 columns]

# %%
#3a) ¿Qué país tiene una mayor población urbana?

# %%
df_who[df_who["Urban_population"] == df_who["Urban_population"].max()]
# Out:
#    Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 36   China         37          7                            3.0
#
#     Adult literacy rate (%)  \
# 36                     90.9
#
#     Gross national income per capita (PPP international $)  \
# 36                                             4660.0
#
#     Net primary school enrolment ratio female (%)  \
# 36                                           96.0
#
#     Net primary school enrolment ratio male (%)  \
# 36                                        100.0
#
#     Population (in thousands) total  Population annual growth rate (%)  ...  \
# 36                        1328474.0                                0.6  ...
#
#     Total_CO2_emissions  Total_income  Total_reserves  \
# 36            5547757.5  1.890000e+12          295.23
#
#     Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 36                      1.250000e+11                           27.3
#
#     Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 36                            27.8                       27.3
#
#     Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 36       527000000.0                     2.95                           40.4
#
# [1 rows x 358 columns]

# %%
#4) ¿El continente donde está situado Spain es el mismo que el de `United States of America?

# %%
sample_spain = df_who[df_who["Country"]=="Spain"]
sample_spain
# Out:
#     Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 168   Spain        169          2                           10.0
#
#      Adult literacy rate (%)  \
# 168                     97.2
#
#      Gross national income per capita (PPP international $)  \
# 168                                            28200.0
#
#      Net primary school enrolment ratio female (%)  \
# 168                                           99.0
#
#      Net primary school enrolment ratio male (%)  \
# 168                                        100.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 168                          43887.0                                1.1  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 168            343701.53  6.780000e+11             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 168                     -5.770000e+10                            4.9
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 168                             4.2                        4.9
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 168        33300000.0                     1.75                           76.7
#
# [1 rows x 358 columns]

# %%
sample_eeuu = df_who[df_who["Country"]=="United States of America"]
sample_eeuu
# Out:
#                       Country  CountryID  Continent  \
# 192  United States of America        193          4
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 192                           43.0                      NaN
#
#      Gross national income per capita (PPP international $)  \
# 192                                            44070.0
#
#      Net primary school enrolment ratio female (%)  \
# 192                                           93.0
#
#      Net primary school enrolment ratio male (%)  \
# 192                                         91.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 192                         302841.0                                1.0  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 192            5776431.5  1.100000e+13             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 192                     -7.140000e+11                            8.0
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 192                             7.1                        8.0
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 192       240000000.0                     1.39                           80.8
#
# [1 rows x 358 columns]

# %%
sample_spain["Continent"].values[0] == sample_eeuu["Continent"].values[0]
# Out:
# np.False_

# %%
df_who.head()
df_who
# Out:
#                 Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0           Afghanistan          1          1                          151.0
# 1               Albania          2          2                           27.0
# 2               Algeria          3          3                            6.0
# 3               Andorra          4          2                            NaN
# 4                Angola          5          3                          146.0
# ..                  ...        ...        ...                            ...
# 197             Vietnam        198          6                           25.0
# 198  West Bank and Gaza        199          1                            NaN
# 199               Yemen        200          1                           83.0
# 200              Zambia        201          3                          161.0
# 201            Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 0                       28.0
# 1                       98.7
# 2                       69.9
# 3                        NaN
# 4                       67.4
# ..                       ...
# 197                     90.3
# 198                      NaN
# 199                     54.1
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 0                                                  NaN
# 1                                               6000.0
# 2                                               5940.0
# 3                                                  NaN
# 4                                               3890.0
# ..                                                 ...
# 197                                             2310.0
# 198                                                NaN
# 199                                             2090.0
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 0                                              NaN
# 1                                             93.0
# 2                                             94.0
# 3                                             83.0
# 4                                             49.0
# ..                                             ...
# 197                                           91.0
# 198                                            NaN
# 199                                           65.0
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 0                                            NaN
# 1                                           94.0
# 2                                           96.0
# 3                                           83.0
# 4                                           51.0
# ..                                           ...
# 197                                         96.0
# 198                                          NaN
# 199                                         85.0
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                            26088.0                                4.0  ...
# 1                             3172.0                                0.6  ...
# 2                            33351.0                                1.5  ...
# 3                               74.0                                1.0  ...
# 4                            16557.0                                2.8  ...
# ..                               ...                                ...  ...
# 197                          86206.0                                1.4  ...
# 198                              NaN                                NaN  ...
# 199                          21732.0                                3.0  ...
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                 692.50           NaN             NaN
# 1                3499.12  4.790000e+09           78.14
# 2              137535.56  6.970000e+10          351.36
# 3                    NaN           NaN             NaN
# 4                8991.46  1.490000e+10           27.13
# ..                   ...           ...             ...
# 197            101826.23  4.480000e+10           47.11
# 198               655.86  3.780000e+09             NaN
# 199             20148.34  1.150000e+10          114.52
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                 NaN                         257.00
# 1                       -2.040000e+09                          18.47
# 2                        4.700000e+09                          40.00
# 3                                 NaN                            NaN
# 4                        9.140000e+09                         164.10
# ..                                ...                            ...
# 197                     -1.940000e+09                          20.20
# 198                               NaN                          28.00
# 199                      8.310000e+08                          82.40
# 200                     -4.470000e+08                         175.30
# 201                     -1.710000e+08                         106.50
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             231.9                     257.00
# 1                              15.5                      18.47
# 2                              31.2                      40.00
# 3                               NaN                        NaN
# 4                             242.5                     164.10
# ..                              ...                        ...
# 197                            23.4                      20.20
# 198                            25.8                      28.00
# 199                            87.9                      82.40
# 200                           163.8                     175.30
# 201                            67.0                     106.50
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0           5740436.0                     5.44                           22.9
# 1           1431793.9                     2.21                           45.4
# 2          20800000.0                     2.61                           63.3
# 3                 NaN                      NaN                            NaN
# 4           8578749.0                     4.14                           53.3
# ..                ...                      ...                            ...
# 197        21900000.0                     2.90                           26.4
# 198         2596216.0                     3.33                           71.6
# 199         5759120.5                     4.37                           27.3
# 200         4017411.0                     1.95                           35.0
# 201         4709965.0                     1.90                           35.9
#
# [202 rows x 358 columns]

# %%
#5) ¿Cuáles son los cinco paises más contaminantes (“Total_CO2_emissions”)?
#Esta es mi pista para una solución elegante: http://pandas.pydata.org/pandas-docs/version/0.19.2/generated/pandas.DataFrame.sort_values.html
result = df_who.sort_values(by="Total_CO2_emissions", ascending=False).head(5)
result
# Out:
#                       Country  CountryID  Continent  \
# 192  United States of America        193          4
# 36                      China         37          7
# 149                    Russia        150          2
# 79                      India         80          7
# 87                      Japan         88          6
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 192                           43.0                      NaN
# 36                             3.0                     90.9
# 149                           28.0                     99.4
# 79                            97.0                     61.0
# 87                             6.0                      NaN
#
#      Gross national income per capita (PPP international $)  \
# 192                                            44070.0
# 36                                              4660.0
# 149                                            12740.0
# 79                                              2460.0
# 87                                             32840.0
#
#      Net primary school enrolment ratio female (%)  \
# 192                                           93.0
# 36                                            96.0
# 149                                           91.0
# 79                                            87.0
# 87                                           100.0
#
#      Net primary school enrolment ratio male (%)  \
# 192                                         91.0
# 36                                         100.0
# 149                                         91.0
# 79                                          90.0
# 87                                         100.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 192                         302841.0                                1.0  ...
# 36                         1328474.0                                0.6  ...
# 149                         143221.0                               -0.5  ...
# 79                         1151751.0                                1.5  ...
# 87                          127953.0                                0.0  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 192            5776431.5  1.100000e+13             NaN
# 36             5547757.5  1.890000e+12          295.23
# 149            1503302.5  3.500000e+11           79.57
# 79             1402359.4  6.440000e+11          111.94
# 87             1230026.8  4.990000e+12             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 192                     -7.140000e+11                           8.00
# 36                       1.250000e+11                          27.30
# 149                      1.040000e+11                          18.30
# 79                      -2.470000e+10                          80.21
# 87                       6.990000e+10                           3.80
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 192                             7.1                       8.00
# 36                             27.8                      27.30
# 149                            20.5                      18.30
# 79                             77.2                      80.21
# 87                              3.5                       3.80
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 192       240000000.0                     1.39                           80.8
# 36        527000000.0                     2.95                           40.4
# 149       104000000.0                    -0.60                           73.0
# 79        314000000.0                     2.07                           28.7
# 87         84100000.0                     0.19                           65.8
#
# [5 rows x 358 columns]

# %%
#6) Observando algunas muestras del fichero puedes establecer la relación entre el identificador del continente y su nombre?
#Es decir, sabemos que Spain está en el continente Europeo y el código del continente es el 2.
#Existen los códigos de continentes: 1, 2, 3, 4, 5, 6, 7
#Nota: Hay dos códigos asociados a Asia.
#Haz las consultas pertinentes al dataframe para construir un diccionario con la siguiente estructura:

# %%
codigoContinentes = {1:"Asia",2:"Europa"} #Al menos hay 7!
print(codigoContinentes[2])
# Out:
# Europa

# %%
codigoContinentes = {1:"Asia",2:"Europa",3:"", 4:""} # TODO...

# %%
df_who[df_who["Continent"] == 6 ]
# Out:
#                               Country  CountryID  Continent  \
# 8                           Australia          9          6
# 25                  Brunei Darussalam         26          6
# 41                       Cook Islands         42          6
# 59                               Fiji         60          6
# 62                   French Polynesia         63          6
# 76                   Hong Kong, China         77          6
# 80                          Indonesia         81          6
# 87                              Japan         88          6
# 91                           Kiribati         92          6
# 92                   Korea, Dem. Rep.         93          6
# 93                        Korea, Rep.         94          6
# 96   Lao People's Democratic Republic         97          6
# 104                      Macao, China        105          6
# 108                          Malaysia        109          6
# 112                  Marshall Islands        113          6
# 116  Micronesia (Federated States of)        117          6
# 119                          Mongolia        120          6
# 123                           Myanmar        124          6
# 125                             Nauru        126          6
# 129                     New Caledonia        130          6
# 130                       New Zealand        131          6
# 134                              Niue        135          6
# 138                             Palau        139          6
# 140                  Papua New Guinea        141          6
# 143                       Philippines        144          6
# 154                             Samoa        155          6
# 162                         Singapore        163          6
# 165                   Solomon Islands        166          6
# 176                            Taiwan        177          6
# 179                          Thailand        180          6
# 180                       Timor-Leste        181          6
# 182                             Tonga        183          6
# 187                            Tuvalu        188          6
# 195                           Vanuatu        196          6
# 197                           Vietnam        198          6
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 8                             16.0                      NaN
# 25                            31.0                     92.7
# 41                             NaN                      NaN
# 59                            35.0                      NaN
# 62                             NaN                      NaN
# 76                             NaN                      NaN
# 80                            54.0                     90.4
# 87                             6.0                      NaN
# 91                             NaN                      NaN
# 92                             0.0                      NaN
# 93                             2.0                      NaN
# 96                           110.0                     68.7
# 104                            NaN                      NaN
# 108                           12.0                     88.7
# 112                            NaN                      NaN
# 116                           44.0                      NaN
# 119                           28.0                     97.8
# 123                           29.0                     89.9
# 125                            NaN                      NaN
# 129                            NaN                      NaN
# 130                           27.0                      NaN
# 134                            NaN                      NaN
# 138                            NaN                      NaN
# 140                           77.0                     57.3
# 143                           55.0                     92.6
# 154                           45.0                     98.6
# 162                            7.0                     92.5
# 165                           72.0                      NaN
# 176                            NaN                      NaN
# 179                           70.0                     92.6
# 180                           49.0                      NaN
# 182                           17.0                     98.9
# 187                            NaN                      NaN
# 195                           92.0                     75.5
# 197                           25.0                     90.3
#
#      Gross national income per capita (PPP international $)  \
# 8                                              33940.0
# 25                                             49900.0
# 41                                                 NaN
# 59                                              4450.0
# 62                                                 NaN
# 76                                                 NaN
# 80                                              3310.0
# 87                                             32840.0
# 91                                              6230.0
# 92                                                 NaN
# 93                                             22990.0
# 96                                              1740.0
# 104                                                NaN
# 108                                            12160.0
# 112                                             8040.0
# 116                                             6070.0
# 119                                             2810.0
# 123                                              510.0
# 125                                                NaN
# 129                                                NaN
# 130                                            25750.0
# 134                                                NaN
# 138                                            14340.0
# 140                                             1630.0
# 143                                             3430.0
# 154                                             5090.0
# 162                                            43300.0
# 165                                             1850.0
# 176                                                NaN
# 179                                             7440.0
# 180                                             5100.0
# 182                                             5470.0
# 187                                                NaN
# 195                                             3480.0
# 197                                             2310.0
#
#      Net primary school enrolment ratio female (%)  \
# 8                                             97.0
# 25                                            94.0
# 41                                            75.0
# 59                                            91.0
# 62                                             NaN
# 76                                             NaN
# 80                                            94.0
# 87                                           100.0
# 91                                            98.0
# 92                                             NaN
# 93                                            93.0
# 96                                            81.0
# 104                                            NaN
# 108                                          100.0
# 112                                           66.0
# 116                                            NaN
# 119                                           93.0
# 123                                          100.0
# 125                                            NaN
# 129                                            NaN
# 130                                           99.0
# 134                                           98.0
# 138                                           94.0
# 140                                            NaN
# 143                                           92.0
# 154                                           91.0
# 162                                           77.0
# 165                                           61.0
# 176                                            NaN
# 179                                           94.0
# 180                                           67.0
# 182                                           94.0
# 187                                            NaN
# 195                                           86.0
# 197                                           91.0
#
#      Net primary school enrolment ratio male (%)  \
# 8                                           96.0
# 25                                          94.0
# 41                                          73.0
# 59                                          91.0
# 62                                           NaN
# 76                                           NaN
# 80                                          97.0
# 87                                         100.0
# 91                                          96.0
# 92                                           NaN
# 93                                         100.0
# 96                                          86.0
# 104                                          NaN
# 108                                        100.0
# 112                                         67.0
# 116                                          NaN
# 119                                         90.0
# 123                                         99.0
# 125                                          NaN
# 129                                          NaN
# 130                                         99.0
# 134                                         99.0
# 138                                         98.0
# 140                                          NaN
# 143                                         90.0
# 154                                         90.0
# 162                                         77.0
# 165                                         62.0
# 176                                          NaN
# 179                                         94.0
# 180                                         70.0
# 182                                         97.0
# 187                                          NaN
# 195                                         88.0
# 197                                         96.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 8                            20530.0                                1.1  ...
# 25                             382.0                                2.1  ...
# 41                              14.0                               -2.5  ...
# 59                             833.0                                0.6  ...
# 62                               NaN                                NaN  ...
# 76                               NaN                                NaN  ...
# 80                          228864.0                                1.2  ...
# 87                          127953.0                                0.0  ...
# 91                              94.0                                1.7  ...
# 92                           23708.0                                0.4  ...
# 93                           48050.0                                0.4  ...
# 96                            5759.0                                1.7  ...
# 104                              NaN                                NaN  ...
# 108                          26114.0                                1.8  ...
# 112                             58.0                                2.2  ...
# 116                            111.0                                0.5  ...
# 119                           2605.0                                0.9  ...
# 123                          48379.0                                0.9  ...
# 125                             10.0                                0.2  ...
# 129                              NaN                                NaN  ...
# 130                           4140.0                                1.0  ...
# 134                              2.0                               -2.2  ...
# 138                             20.0                                0.5  ...
# 140                           6202.0                                2.2  ...
# 143                          86264.0                                2.0  ...
# 154                            185.0                                0.8  ...
# 162                           4382.0                                1.3  ...
# 165                            484.0                                2.4  ...
# 176                              NaN                                NaN  ...
# 179                          63444.0                                0.7  ...
# 180                           1114.0                                4.3  ...
# 182                            100.0                                0.5  ...
# 187                             10.0                                0.4  ...
# 195                            221.0                                2.5  ...
# 197                          86206.0                                1.4  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 8              368858.53  4.680000e+11             NaN
# 25               5891.71  4.830000e+09             NaN
# 41                   NaN           NaN             NaN
# 59               1641.47  1.860000e+09          137.36
# 62                685.17  3.450000e+09             NaN
# 76              38559.94  2.080000e+11             NaN
# 80             419593.94  2.080000e+11           26.57
# 87            1230026.80  4.990000e+12             NaN
# 91                 25.65  5.190000e+07             NaN
# 92              82615.88           NaN             NaN
# 93             452218.22  6.390000e+11             NaN
# 96               1432.62  2.350000e+09           11.49
# 104              2235.04  1.040000e+10             NaN
# 108            239834.45  1.120000e+11          135.55
# 112                  NaN           NaN             NaN
# 116                  NaN           NaN             NaN
# 119              8789.94  1.250000e+09           32.44
# 123             11314.43           NaN           13.38
# 125                  NaN           NaN             NaN
# 129              2638.08  2.680000e+09             NaN
# 130             29945.87  6.270000e+10             NaN
# 134                  NaN           NaN             NaN
# 138                  NaN           NaN             NaN
# 140              4437.10  3.700000e+09           39.79
# 143             74958.11  9.440000e+10           29.93
# 154               150.22  2.860000e+08           12.46
# 162             56275.38  1.130000e+11             NaN
# 165               175.87  3.230000e+08           57.36
# 176            245806.77           NaN             NaN
# 179            270894.20  1.570000e+11          100.87
# 180                  NaN           NaN             NaN
# 182               117.25  1.670000e+08           57.30
# 187                  NaN           NaN             NaN
# 195                87.94  2.560000e+08           81.85
# 197            101826.23  4.480000e+10           47.11
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 8                       -1.280000e+10                           5.90
# 25                                NaN                           8.80
# 41                                NaN                            NaN
# 59                       1.980000e+07                          18.10
# 62                                NaN                            NaN
# 76                       2.220000e+10                            NaN
# 80                       1.150000e+10                          38.40
# 87                       6.990000e+10                           3.80
# 91                      -2.080000e+07                          66.00
# 92                                NaN                          55.00
# 93                       1.900000e+10                           5.08
# 96                      -8.230000e+07                          83.40
# 104                      4.250000e+09                            NaN
# 108                      3.080000e+10                          12.40
# 112                               NaN                            NaN
# 116                               NaN                            NaN
# 119                     -9.080000e+07                          50.90
# 123                      7.230000e+08                         106.00
# 125                               NaN                            NaN
# 129                               NaN                            NaN
# 130                     -2.560000e+09                           6.70
# 134                               NaN                            NaN
# 138                               NaN                            NaN
# 140                      8.880000e+08                          69.40
# 143                     -9.110000e+09                          31.50
# 154                     -1.160000e+08                          29.98
# 162                      3.490000e+10                           3.00
# 165                      2.330000e+07                          77.70
# 176                               NaN                            NaN
# 179                     -3.750000e+09                           9.00
# 180                               NaN                            NaN
# 182                     -9.460000e+07                          24.48
# 187                               NaN                            NaN
# 195                     -3.740000e+07                          39.94
# 197                     -1.940000e+09                          20.20
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 8                               5.1                       5.90
# 25                              7.2                       8.80
# 41                              NaN                        NaN
# 59                             15.3                      18.10
# 62                              NaN                        NaN
# 76                              NaN                        NaN
# 80                             42.7                      38.40
# 87                              3.5                       3.80
# 91                              NaN                      66.00
# 92                              NaN                      55.00
# 93                              6.8                       5.08
# 96                             84.3                      83.40
# 104                             NaN                        NaN
# 108                             6.1                      12.40
# 112                             NaN                        NaN
# 116                             NaN                        NaN
# 119                            39.7                      50.90
# 123                            98.8                     106.00
# 125                             NaN                        NaN
# 129                             NaN                        NaN
# 130                             6.1                       6.70
# 134                             NaN                        NaN
# 138                             NaN                        NaN
# 140                            83.6                      69.40
# 143                            30.9                      31.50
# 154                             NaN                      29.98
# 162                             3.0                       3.00
# 165                             NaN                      77.70
# 176                             NaN                        NaN
# 179                            13.7                       9.00
# 180                             NaN                        NaN
# 182                             NaN                      24.48
# 187                             NaN                        NaN
# 195                            43.0                      39.94
# 197                            23.4                      20.20
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 8        1.800000e+07                     1.54                           88.2
# 25       2.747658e+05                     2.86                           73.5
# 41                NaN                      NaN                            NaN
# 59       4.206474e+05                     1.61                           50.8
# 62       1.321618e+05                     1.20                           51.7
# 76       6.813200e+06                     0.37                          100.0
# 80       1.060000e+08                     3.93                           48.1
# 87       8.410000e+07                     0.19                           65.8
# 91       4.692600e+04                     3.08                           47.4
# 92       1.450000e+07                     0.89                           61.6
# 93       3.900000e+07                     0.74                           80.8
# 96       1.166766e+06                     3.27                           20.6
# 104      4.730900e+05                     1.16                          100.0
# 108      1.730000e+07                     3.46                           67.3
# 112               NaN                      NaN                            NaN
# 116               NaN                      NaN                            NaN
# 119      1.448118e+06                     1.59                           56.7
# 123      1.470000e+07                     2.56                           30.6
# 125               NaN                      NaN                            NaN
# 129      1.493634e+05                     2.47                           63.7
# 130      3.563422e+06                     1.24                           86.2
# 134               NaN                      NaN                            NaN
# 138               NaN                      NaN                            NaN
# 140      8.133411e+05                     2.54                           13.4
# 143      5.300000e+07                     3.38                           62.7
# 154      4.118128e+04                     1.18                           22.4
# 162      4.341800e+06                     2.41                          100.0
# 165      8.031123e+04                     4.02                           17.0
# 176               NaN                      NaN                            NaN
# 179      2.030000e+07                     1.44                           32.3
# 180               NaN                      NaN                            NaN
# 182      2.384664e+04                     1.04                           24.0
# 187               NaN                      NaN                            NaN
# 195      5.061101e+04                     4.11                           23.5
# 197      2.190000e+07                     2.90                           26.4
#
# [35 rows x 358 columns]

# %%
#7) Una vez identificado el nombre de los continentes, 
#¿puedes cambiar la columna de identificadores de continentes por sus respectivos nombres?

df_who.loc[df_who["Continent"] == 1, "Continent"] = "Eurasia"
df_who
# Out:
#                 Country  CountryID Continent  Adolescent fertility rate (%)  \
# 0           Afghanistan          1   Eurasia                          151.0
# 1               Albania          2         2                           27.0
# 2               Algeria          3         3                            6.0
# 3               Andorra          4         2                            NaN
# 4                Angola          5         3                          146.0
# ..                  ...        ...       ...                            ...
# 197             Vietnam        198         6                           25.0
# 198  West Bank and Gaza        199   Eurasia                            NaN
# 199               Yemen        200   Eurasia                           83.0
# 200              Zambia        201         3                          161.0
# 201            Zimbabwe        202         3                          101.0
#
#      Adult literacy rate (%)  \
# 0                       28.0
# 1                       98.7
# 2                       69.9
# 3                        NaN
# 4                       67.4
# ..                       ...
# 197                     90.3
# 198                      NaN
# 199                     54.1
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 0                                                  NaN
# 1                                               6000.0
# 2                                               5940.0
# 3                                                  NaN
# 4                                               3890.0
# ..                                                 ...
# 197                                             2310.0
# 198                                                NaN
# 199                                             2090.0
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 0                                              NaN
# 1                                             93.0
# 2                                             94.0
# 3                                             83.0
# 4                                             49.0
# ..                                             ...
# 197                                           91.0
# 198                                            NaN
# 199                                           65.0
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 0                                            NaN
# 1                                           94.0
# 2                                           96.0
# 3                                           83.0
# 4                                           51.0
# ..                                           ...
# 197                                         96.0
# 198                                          NaN
# 199                                         85.0
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                            26088.0                                4.0  ...
# 1                             3172.0                                0.6  ...
# 2                            33351.0                                1.5  ...
# 3                               74.0                                1.0  ...
# 4                            16557.0                                2.8  ...
# ..                               ...                                ...  ...
# 197                          86206.0                                1.4  ...
# 198                              NaN                                NaN  ...
# 199                          21732.0                                3.0  ...
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                 692.50           NaN             NaN
# 1                3499.12  4.790000e+09           78.14
# 2              137535.56  6.970000e+10          351.36
# 3                    NaN           NaN             NaN
# 4                8991.46  1.490000e+10           27.13
# ..                   ...           ...             ...
# 197            101826.23  4.480000e+10           47.11
# 198               655.86  3.780000e+09             NaN
# 199             20148.34  1.150000e+10          114.52
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                 NaN                         257.00
# 1                       -2.040000e+09                          18.47
# 2                        4.700000e+09                          40.00
# 3                                 NaN                            NaN
# 4                        9.140000e+09                         164.10
# ..                                ...                            ...
# 197                     -1.940000e+09                          20.20
# 198                               NaN                          28.00
# 199                      8.310000e+08                          82.40
# 200                     -4.470000e+08                         175.30
# 201                     -1.710000e+08                         106.50
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             231.9                     257.00
# 1                              15.5                      18.47
# 2                              31.2                      40.00
# 3                               NaN                        NaN
# 4                             242.5                     164.10
# ..                              ...                        ...
# 197                            23.4                      20.20
# 198                            25.8                      28.00
# 199                            87.9                      82.40
# 200                           163.8                     175.30
# 201                            67.0                     106.50
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0           5740436.0                     5.44                           22.9
# 1           1431793.9                     2.21                           45.4
# 2          20800000.0                     2.61                           63.3
# 3                 NaN                      NaN                            NaN
# 4           8578749.0                     4.14                           53.3
# ..                ...                      ...                            ...
# 197        21900000.0                     2.90                           26.4
# 198         2596216.0                     3.33                           71.6
# 199         5759120.5                     4.37                           27.3
# 200         4017411.0                     1.95                           35.0
# 201         4709965.0                     1.90                           35.9
#
# [202 rows x 358 columns]

# %%
#8) Puedes crear un nuevo dataframe con aquellos paises que sean de Europa?
df_who[df_who["Continent" == 2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[101], line 2
#       1 #8) Puedes crear un nuevo dataframe con aquellos paises que sean de Europa?
# ----> 2 df_who[df_who["Continent" == 2]]
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/Library/Python/3.14/lib/python/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: False

# %%
df_who.sort_values("Total_CO2_emissions", ascending=False).head()
# Out:
#                       Country  CountryID Continent  \
# 192  United States of America        193         4
# 36                      China         37         7
# 149                    Russia        150         2
# 79                      India         80         7
# 87                      Japan         88         6
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 192                           43.0                      NaN
# 36                             3.0                     90.9
# 149                           28.0                     99.4
# 79                            97.0                     61.0
# 87                             6.0                      NaN
#
#      Gross national income per capita (PPP international $)  \
# 192                                            44070.0
# 36                                              4660.0
# 149                                            12740.0
# 79                                              2460.0
# 87                                             32840.0
#
#      Net primary school enrolment ratio female (%)  \
# 192                                           93.0
# 36                                            96.0
# 149                                           91.0
# 79                                            87.0
# 87                                           100.0
#
#      Net primary school enrolment ratio male (%)  \
# 192                                         91.0
# 36                                         100.0
# 149                                         91.0
# 79                                          90.0
# 87                                         100.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 192                         302841.0                                1.0  ...
# 36                         1328474.0                                0.6  ...
# 149                         143221.0                               -0.5  ...
# 79                         1151751.0                                1.5  ...
# 87                          127953.0                                0.0  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 192            5776431.5  1.100000e+13             NaN
# 36             5547757.5  1.890000e+12          295.23
# 149            1503302.5  3.500000e+11           79.57
# 79             1402359.4  6.440000e+11          111.94
# 87             1230026.8  4.990000e+12             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 192                     -7.140000e+11                           8.00
# 36                       1.250000e+11                          27.30
# 149                      1.040000e+11                          18.30
# 79                      -2.470000e+10                          80.21
# 87                       6.990000e+10                           3.80
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 192                             7.1                       8.00
# 36                             27.8                      27.30
# 149                            20.5                      18.30
# 79                             77.2                      80.21
# 87                              3.5                       3.80
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 192       240000000.0                     1.39                           80.8
# 36        527000000.0                     2.95                           40.4
# 149       104000000.0                    -0.60                           73.0
# 79        314000000.0                     2.07                           28.7
# 87         84100000.0                     0.19                           65.8
#
# [5 rows x 358 columns]

# %%
#9) ¿Cuáles son los paises más contaminantes de Europa?

# %%
#10) Calcula la cantidad de ayuda recibida por cada municipio en función del número total de habitantes.
import pandas as pd
import random

random.seed(0)

nombres = [f'Municipio{i}' for i in range(1, 11)]

data_municipios = {
    'Nombre': nombres,
    'Código Postal': [random.randint(10000, 99999) for _ in range(10)],
    'Población': [random.randint(1000, 50000) for _ in range(10)]  # Añadimos un atributo aleatorio, en este caso "Población"
}

df_municipios = pd.DataFrame(data_municipios)


data_ayudas = {
    'Nombre':  [f'Municipio{i}' for i in range(1, 11)],
    'Ayuda Económica (en euros)': [random.randint(1000, 10000) for _ in range(10)],
    'Número de Beneficiarios': [random.randint(10, 100) for _ in range(10)]
}

df_ayudas = pd.DataFrame(data_ayudas)

print("Dataframe de Municipios:")
print(df_municipios)

print("\nDataframe de Ayudas:")
print(df_ayudas)

df_merged = pd.merge(df_municipios, df_ayudas, on="Nombre")
df_merged["Ayuda por Habitante (€)"] = (
    df_merged["Ayuda Económica (en euros)"] / df_merged["Población"]
)
df_result = df_merged[["Nombre", "Población", "Ayuda Económica (en euros)", "Ayuda por Habitante (€)"]]
print(df_result)
# Out:
# Dataframe de Municipios:
#         Nombre  Código Postal  Población
# 0   Municipio1          60494      39232
# 1   Municipio2          65125      15315
# 2   Municipio3          15306      34075
# 3   Municipio4          43936      10127
# 4   Municipio5          77013      19470
# 5   Municipio6          73691      10158
# 6   Municipio7          63075       7214
# 7   Municipio8          49755      41525
# 8   Municipio9          72468      17417
# 9  Municipio10          56930      35902
#
# Dataframe de Ayudas:
#         Nombre  Ayuda Económica (en euros)  Número de Beneficiarios
# 0   Municipio1                        3407                       88
# 1   Municipio2                        6081                       91
# 2   Municipio3                        2618                       36
# 3   Municipio4                        2208                       80
# 4   Municipio5                        6409                       71
# 5   Municipio6                        8735                       66
# 6   Municipio7                        2649                       76
# 7   Municipio8                        6796                       43
# 8   Municipio9                        8113                       17
# 9  Municipio10                        6180                       80
#         Nombre  Población  Ayuda Económica (en euros)  Ayuda por Habitante (€)
# 0   Municipio1      39232                        3407                 0.086842
# 1   Municipio2      15315                        6081                 0.397062
# 2   Municipio3      34075                        2618                 0.076831
# 3   Municipio4      10127                        2208                 0.218031
# 4   Municipio5      19470                        6409                 0.329173
# 5   Municipio6      10158                        8735                 0.859913
# 6   Municipio7       7214                        2649                 0.367203
# 7   Municipio8      41525                        6796                 0.163660
# 8   Municipio9      17417                        8113                 0.465809
# 9  Municipio10      35902                        6180                 0.172135

# %%
df_nou = df_municipios.merge(df_ayudas,on="Nombre")
df_nou["Ayuda por persona"] = df_nou["Ayuda Económica (en euros)"] / df_nou["Población"]
df_nou
# Out:
#         Nombre  Código Postal  Población  Ayuda Económica (en euros)  \
# 0   Municipio1          60494      39232                        3407
# 1   Municipio2          65125      15315                        6081
# 2   Municipio3          15306      34075                        2618
# 3   Municipio4          43936      10127                        2208
# 4   Municipio5          77013      19470                        6409
# 5   Municipio6          73691      10158                        8735
# 6   Municipio7          63075       7214                        2649
# 7   Municipio8          49755      41525                        6796
# 8   Municipio9          72468      17417                        8113
# 9  Municipio10          56930      35902                        6180
#
#    Número de Beneficiarios  Ayuda por persona
# 0                       88           0.086842
# 1                       91           0.397062
# 2                       36           0.076831
# 3                       80           0.218031
# 4                       71           0.329173
# 5                       66           0.859913
# 6                       76           0.367203
# 7                       43           0.163660
# 8                       17           0.465809
# 9                       80           0.172135

# %%
#Usando el fichero climaMallorca.csv, se pide: 
#11) ¿Cual es la temperatura máxima cuando el viento es inferior a 10? ¿Cuántas muestras hay?
